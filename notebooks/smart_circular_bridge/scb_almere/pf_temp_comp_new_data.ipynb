# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sep005_io_fbgs
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import numpy as np

from filter_tc.particle_filter import ParticleFilter

# %%
data_path = "../../../data/scb/almere/strain/raw/SCBALM/TDD/TDD_fiber/2022/09/01/20220901-1040 02-SCB.txt.gz"
sep005_fbgs = sep005_io_fbgs.read_fbgs(data_path)

# %%
# TODO: @Wout: The naming of the sensor signals isn't the same as previously,
# it was nice to have the old format with sensor position, structure and the type of sensor (temperature or strain). 
# Now it's just the sensor line nad number, which is not very informative.

# create the measurement and temperature datasets
measurements = []
inputs = []
for fbg_data in sep005_fbgs:
    if 'B-C-N' in fbg_data['name']:
        print(fbg_data['name'])
        measurements.append(fbg_data)
    if 'T-B-S' in fbg_data['name']:
        print(fbg_data['name'])
        inputs.append(fbg_data)
# Out:
# T-B-S
# B-C-N-01
# B-C-N-02
# B-C-N-03
# B-C-N-04
# B-C-N-05
# B-C-N-06
# B-C-N-07

# %%
import json
pfb_states = json.load(open('pfb_states.json', 'r'))
import pickle
pfb_states = pickle.load(open('pfb_states.pkl', 'rb'))

# %%
pfb_states['B-C-N-01']['event_distribution']
# Out:
# 'gamma'

# %%
from filter_tc.particle_filter import ParticleFilterBank
pfb = ParticleFilterBank.from_states(pfb_states)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 from filter_tc.particle_filter import ParticleFilterBank
# ----> 2 pfb = ParticleFilterBank.from_states(pfb_states)
#
# File c:\users\max\documents\owi_lab\code\packages\filter_tc\filter_tc\particle_filter.py:145, in ParticleFilterBank.from_states(cls, collected_states)
#     140     if isinstance(collected_states[sensor][var], list):
#     141         collected_states[sensor][var] = np.array(collected_states[sensor][var])
#     142         distribution = \
#     143             getattr(
#     144                 sp.stats,
# --> 145                 collected_states[sensor]['event_distribution']['dist_name']
#     146                 )(
#     147                     collected_states[sensor]['event_distribution']['dist_args'],
#     148                     **collected_states[sensor]['event_distribution']['dist_kwds']
#     149                 )
#     150         collected_states[sensor][var] = distribution
#     152 states[sensor] = collected_states[sensor]
#
# TypeError: string indices must be integers, not 'str'

# %%
pfb[0].alpha
# Out:
# 2.520541362143402

# %%
filtered = pfb.filter(measurements, inputs)

# %%
#cProfile.run('pfb.filter_parallel_GPT(measurements, inputs)')

# %%
for i in range(len(filtered)):
    fig, ax1 = plt.subplots(figsize=(20,5))
    ax2 = ax1.twinx()

    # Plot the data on the respective axes
    ax2.plot(inputs[0]['data'], alpha = 0.1, label='temperaure inputs', color='tab:red')
    ax1.plot(filtered[i]['data'], label = 'pf filtered '+ filtered[i]['name'], color='tab:blue')
    ax1.plot(measurements[i]['data'], label='strain measurement ' + measurements[i]['name'], color='tab:orange')
    plt.legend()
    # Set the labels and limits for the axes
    ax1.set_xlabel('Time (DD HH:MMs)')
    ax1.set_ylabel('strain a', color='blue')
    ax2.set_ylabel('Temperature b', color='red')
    plt.title('Strain and temperature trend data for ' + measurements[i]['name'])
    # Show the plot
    plt.show()
